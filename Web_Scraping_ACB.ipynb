# %%
import pandas as pd

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2022/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df1 in dfs:
    print(df1)

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2021/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df2 in dfs:
    print(df2)

dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2020/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df3 in dfs:
    print(df4)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2019/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df4 in dfs:
    print(df4)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2018/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df5 in dfs:
    print(df5)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2017/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df6 in dfs:
    print(df6)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2016/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df7 in dfs:
    print(df7)
    
dfs = pd.read_html('https://basketball.realgm.com/international/league/4/Spanish-ACB/stats/2015/Averages/Qualified/All/points/All/desc/1/Regular_Season',header=0)
for df8 in dfs:
    print(df8)

#Actualmente estamos en la tmeporada 2021-2022    
df1.to_csv("2021-2022.csv")
df2.to_csv("2020-2021.csv")
df3.to_csv('2019-2020.csv')
df4.to_csv('2018-2019.csv')
df5.to_csv('2017-2018.csv')
df6.to_csv('2016-2017.csv')
df7.to_csv('2015-2016.csv')
df8.to_csv('2014-2015.csv')
# Out:
#       #              Player   Team  GP   MPG  ...  RPG  APG  SPG  BPG   PPG
# 0     1         Dzanan Musa    BRE  15  30.8  ...  4.8  3.1  1.4  0.3  19.1
# 1     2         Obi Emegano    MON  14  30.6  ...  3.0  2.4  0.7  0.0  17.1
# 2     3       Isaiah Taylor    MUR  15  24.1  ...  1.7  2.6  0.5  0.1  16.4
# 3     4      Nikola Mirotic    FCB  13  23.3  ...  5.9  1.1  0.5  0.6  15.2
# 4     5         Dylan Ennis    GCN  16  25.3  ...  2.1  1.9  1.1  0.4  15.0
# ..  ...                 ...    ...  ..   ...  ...  ...  ...  ...  ...   ...
# 95   96      Dairis Bertans  BETIS  15  24.1  ...  1.4  1.1  0.8  0.0   7.1
# 96   97        Yankuba Sima    MAN  16  16.9  ...  4.7  0.8  0.4  0.4   6.9
# 97   98        Chris Kramer    GCN  16  18.5  ...  2.1  1.9  0.9  0.1   6.9
# 98   99  Khadeen Carrington  BETIS  10  19.0  ...  1.9  1.1  1.2  0.0   6.9
# 99  100      Elias Valtonen    MAN  15  20.0  ...  2.0  0.5  1.1  0.3   6.8
#
# [100 rows x 23 columns]
# ...
